# %%
# %%writefile StudentGradeTracker.java
# import java.util.Scanner;
#
# public class StudentGradeTracker {
#     public static void main(String[] args) {
#
#         Scanner sc = new Scanner(System.in);
#
#         System.out.print("Enter number of students: ");
#         int n = sc.nextInt();
#
#         String[] names = new String[n];
#         double[] marks = new double[n];
#
#         double total = 0;
#         double highest = -1;
#         double lowest = 101;
#         String highestStudent = "";
#         String lowestStudent = "";
#
#         for (int i = 0; i < n; i++) {
#             sc.nextLine();
#
#             System.out.print("Enter student name: ");
#             names[i] = sc.nextLine();
#
#             System.out.print("Enter marks: ");
#             marks[i] = sc.nextDouble();
#
#             total += marks[i];
#
#             if (marks[i] > highest) {
#                 highest = marks[i];
#                 highestStudent = names[i];
#             }
#
#             if (marks[i] < lowest) {
#                 lowest = marks[i];
#                 lowestStudent = names[i];
#             }
#         }
#
#         double average = total / n;
#
#         System.out.println("\n===== Student Report =====");
#
#         for (int i = 0; i < n; i++) {
#             System.out.println(names[i] + " : " + marks[i]);
#         }
#
#         System.out.println("\nAverage Marks: " + average);
#         System.out.println("Highest Marks: " + highest + " (" + highestStudent + ")");
#         System.out.println("Lowest Marks: " + lowest + " (" + lowestStudent + ")");
#
#         sc.close();
#     }
# }
# Out:
# Writing StudentGradeTracker.java

# %%
# Compile the Java code
# !javac StudentGradeTracker.java

# %%
# Run the compiled Java code
# !java StudentGradeTracker
# Out:
# Enter number of students: 5
# Enter student name: moiz
# Enter marks: 58
# Enter student name: laiba
# Enter marks: 67
# Enter student name: ariba
# Enter marks: 45
# Enter student name: fatima
# Enter marks: 67
# Enter student name: farida
# Enter marks: 87
#
# ===== Student Report =====
# moiz  : 58.0
# laiba : 67.0
# ariba : 45.0
# fatima  : 67.0
# farida  : 87.0
#
# Average Marks: 64.8
# Highest Marks: 87.0 (farida )
# Lowest Marks: 45.0 (ariba)
